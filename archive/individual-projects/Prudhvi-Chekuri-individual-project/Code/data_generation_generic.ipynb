# %% [markdown]
# # Notebook Description
#
# - **Purpose**: This notebook aims to augment the math problem dataset from [this](https://www.kaggle.com/competitions/classification-of-math-problems-by-kasut-academy/overview) Kaggle competition by generating synthetic data, particularly for classes with fewer samples, to achieve a more balanced class distribution (targeting 3000 samples per class).
# - **Methodology**: It utilizes AWS Bedrock, specifically the anthropic.claude-3-5-sonnet model for generation.
# - **Generation Strategy**: For each underrepresented topic, it takes example problems from the original dataset within that topic. It prompts the Bedrock model to generate a batch of new math problems inspired by the example, matching the topic and complexity but using varied contexts and phrasing. The prompt instructs the model to return a list of problems separated by a specific delimiter (\n---\n) for easier parsing.
# - **Implementation**: The generation process is parallelized using Python's ThreadPoolExecutor for efficiency. It includes error handling for potential Bedrock API issues like throttling, incorporating retries with exponential backoff.
# Output: The newly generated questions and their corresponding labels are combined into a pandas DataFrame and saved as CSV.

# %% [markdown]
# # Import Libraries

# %%
import re
import os
import boto3
import json
import time
import pandas as pd
from botocore.exceptions import ClientError
from concurrent.futures import ThreadPoolExecutor

# %%
# Set if needed.
if False:
    os.environ['AWS_ACCESS_KEY_ID'] = ''
    os.environ['AWS_SECRET_ACCESS_KEY'] = ''
    os.environ['AWS_SESSION_TOKEN'] = ''
    os.environ['AWS_DEFAULT_REGION'] = ''

    print(boto3.client('sts').get_caller_identity())

# %% [markdown]
# # Initialize Bedrock and Load Data

# %%
try:
    bedrock = boto3.client('bedrock-runtime', region_name='us-east-1')
    print("Bedrock client initialized successfully.")
except Exception as e:
    print(f"Failed to initialize Bedrock client: {e}")
    print("Ensure AWS credentials (including session token) are set in ~/.aws/credentials or environment variables.")
    bedrock = None


TOPICS = {
    0: "Algebra",
    1: "Geometry and Trigonometry",
    2: "Calculus and Analysis",
    3: "Probability and Statistics",
    4: "Number Theory",
    5: "Combinatorics and Discrete Math",
    6: "Linear Algebra",
    7: "Abstract Algebra and Topology"
}

# Load dataset
train_data_path = "https://raw.githubusercontent.com/PrudhvirajuChekuri/Final-Project-Group8/refs/heads/master/code/data/train.csv"
train_df = pd.read_csv(train_data_path)
label_counts = train_df['label'].value_counts()
target_samples = 3000
# Out:
# Bedrock client initialized successfully.

# %% [markdown]
# # Create and Test Function to Generate Questions

# %%
# Function to generate multiple questions in one API call
def generate_questions_batch(original_question, topic, num_questions=5, retries=3):
    if not bedrock:
        return [f"Mock question {i+1} for {topic}: Similar to '{original_question}'" for i in range(num_questions)]
    
    prompt = f"""
You are a math expert tasked with generating {num_questions} new math problems for a specific topic, inspired by an example problem but with distinct structure and wording.

### Topic:
{topic}

### Example Problem:
{original_question}

### Instructions:
1. Generate exactly {num_questions} new math problems in the topic of {topic}.
2. Each problem must have a different context (e.g., use dice, cards, experiments, or surveys instead of balls/urns if the example uses those).
3. Use varied phrasing and question styles (e.g., ask for probability as a decimal, percentage, simplified fraction, conditional probability, or expected value).
4. Match the mathematical complexity and key concepts of the example problem.
5. Ensure all problems are valid, solvable, and suitable for a Kaggle competition.
6. Avoid repetitive phrases like "expressed as a fraction in lowest terms" and diversify wording.
7. Return the problems as a list of strings, with each problem separated by exactly "\n---\n" (newline, three dashes, newline).
8. Each problem should be a single string. Do not include explanations, solutions, or numbering.
"""
    for attempt in range(retries):
        try:
            response = bedrock.invoke_model(
                modelId='anthropic.claude-3-5-sonnet-20240620-v1:0',
                body=json.dumps({
                    "anthropic_version": "bedrock-2023-05-31",
                    "max_tokens": 1000,  # Increased for multiple questions
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                })
            )
            result = json.loads(response['body'].read().decode('utf-8'))
            text = result['content'][0]['text'].strip()
            # Parse delimited list
            questions = re.split(r'\n---\n', text)
            questions = [q.strip() for q in questions if q.strip()]
            if len(questions) < num_questions:
                print(f"Warning: Got {len(questions)} questions instead of {num_questions}. Retrying...")
                continue
            return questions[:num_questions]
        except ClientError as e:
            if "Throttling" in str(e):
                print(f"Throttling detected. Retrying {attempt+1}/{retries} after delay...")
                time.sleep(2 ** attempt)  # Exponential backoff
            elif "AccessDenied" in str(e):
                print("Credentials lack Bedrock permissions. Contact your instructor.")
                return None
            elif "InvalidClientTokenId" in str(e) or "SignatureDoesNotMatch" in str(e):
                print("Invalid or expired credentials. Refresh from your portal.")
                return None
            elif "ValidationError" in str(e):
                print("Invalid model ID. Verify with 'aws bedrock list-foundation-models'.")
                return None
            else:
                print(f"Bedrock error: {e}")
                return None
        except Exception as e:
            print(f"Unexpected error: {e}")
            return None
    print(f"Failed to generate questions after {retries} attempts.")
    return None

# Parallel generation function
def generate_questions_parallel(original_questions, topic, target_count, batch_size=5, max_workers=8):
    questions_needed = target_count
    generated_questions = []
    batches = (questions_needed + batch_size - 1) // batch_size  # Ceiling division
    
    print(f"Generating {questions_needed} questions in {batches} batches...")
    start_time = time.time()
    
    def process_batch(index):
        # Cycle through original questions
        original = original_questions[index % len(original_questions)]
        result = generate_questions_batch(original, topic, batch_size)
        return result if result else []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Generate batches in parallel
        results = list(executor.map(process_batch, range(batches)))
    
    # Flatten results
    for batch in results:
        generated_questions.extend(batch)
    
    elapsed = time.time() - start_time
    print(f"Generated {len(generated_questions)} questions in {elapsed:.2f} seconds.")
    return generated_questions[:questions_needed]

# Test the function
if __name__ == "__main__":
    try:
        train_df = pd.read_csv('train.')
        # Filter for Probability and Statistics (label=3)
        topic = TOPICS[3]
        sample_questions = train_df[train_df['label'] == 3]['Question'].head(5).tolist()
        if not sample_questions:
            print("Error: No questions found for Probability and Statistics.")
            exit(1)
        
        print(f"Testing generation for {topic}...")
        target_count = 400
        generated = generate_questions_parallel(sample_questions, topic, target_count)
        
        if generated:
            print(f"Sample generated questions:")
            for i, q in enumerate(generated[:5], 1):
                print(f"{i}. {q}")
        else:
            print("Failed to generate questions.")
    except FileNotFoundError:
        print("Error: train.csv not found.")
    except KeyError:
        print("Error: Required columns ('Question', 'label') not found. Available columns:", train_df.columns.tolist())
# Out:
# Bedrock client initialized successfully.
# Testing generation for Probability and Statistics...
# Generating 400 questions in 80 batches...
# Generated 400 questions in 86.91 seconds.
# Sample generated questions:
# 1. Here are 5 new math problems on Probability and Statistics based on your requirements:
#
# A card game involves drawing from a standard 52-card deck without replacement. Players continue drawing until they have three cards of the same suit or five cards total. What is the probability, as a percentage rounded to two decimal places, that a player will draw exactly five cards?
# 2. In a psychology experiment, subjects are shown a series of 10 images and must remember them in order. The probability of remembering each image correctly is 0.8, independent of other images. Calculate the expected number of images remembered correctly in their proper sequence from the beginning before the first mistake.
# 3. A factory produces widgets with a 5% defect rate. Quality control randomly selects 20 widgets for inspection. What is the probability that they find at least one defective widget? Express your answer as a decimal rounded to four places.
# 4. Six fair dice are rolled simultaneously. Let X be the number of dice showing an even number. Find P(X = 3 | X ≤ 4), the conditional probability that exactly three dice show even numbers given that at most four dice show even numbers.
# 5. A survey asks 100 people to rate a product on a scale from 1 to 5 stars. The ratings follow a discrete probability distribution where P(1 star) = 0.1, P(2 stars) = 0.2, P(3 stars) = 0.3, P(4 stars) = 0.3, and P(5 stars) = 0.1. What is the probability that the average rating from this survey will be greater than 3.5 stars? Give your answer as a fraction in simplest form.

# %%
generated[:10]
# Out:
# ['Here are 5 new math problems on Probability and Statistics based on your requirements:\n\nA card game involves drawing from a standard 52-card deck without replacement. Players continue drawing until they have three cards of the same suit or five cards total. What is the probability, as a percentage rounded to two decimal places, that a player will draw exactly five cards?',
#  'In a psychology experiment, subjects are shown a series of 10 images and must remember them in order. The probability of remembering each image correctly is 0.8, independent of other images. Calculate the expected number of images remembered correctly in their proper sequence from the beginning before the first mistake.',
#  'A factory produces widgets with a 5% defect rate. Quality control randomly selects 20 widgets for inspection. What is the probability that they find at least one defective widget? Express your answer as a decimal rounded to four places.',
#  'Six fair dice are rolled simultaneously. Let X be the number of dice showing an even number. Find P(X = 3 | X ≤ 4), the conditional probability that exactly three dice show even numbers given that at most four dice show even numbers.',
#  'A survey asks 100 people to rate a product on a scale from 1 to 5 stars. The ratings follow a discrete probability distribution where P(1 star) = 0.1, P(2 stars) = 0.2, P(3 stars) = 0.3, P(4 stars) = 0.3, and P(5 stars) = 0.1. What is the probability that the average rating from this survey will be greater than 3.5 stars? Give your answer as a fraction in simplest form.',
#  'Here are 5 new math problems on Probability and Statistics:\n\nA survey asks participants to rate their satisfaction on a scale from 1 to 10. Let [x] denote the greatest integer not exceeding x. If a response is considered "positive" when [√(rating)] is odd, what is the probability of a randomly selected response being positive?',
#  'In a game, players roll a fair six-sided die and win if the result x satisfies: 2^[log₃(x)] is even. What is the expected number of rolls before a player wins?',
#  'A random variable X follows a uniform distribution over (0, 2π). Define Y = [sin(X)], where [x] is the floor function. Calculate P(Y = 0).',
#  "In a coding competition, a programmer's skill level S is uniformly distributed between 0 and 100. Their chance of solving a problem is [S/10]/10, where [x] denotes the floor function. What's the probability that a randomly selected programmer solves the problem?",
#  "Let f(x) = [e^x], where [x] is the floor function and e is Euler's number. If X is a random variable uniformly distributed over the interval (0, 1), find the probability that f(X) is prime.",
#  'Here are 5 new math problems on Probability and Statistics based on your requirements:\n\nA standard deck of 52 cards contains 13 hearts. If you draw 3 cards without replacement, what is the probability that all three cards are hearts? Express your answer as a decimal rounded to four decimal places.',
#  'In a bag of 50 marbles, 30 are blue and 20 are green. If you select 5 marbles at random, what is the percentage chance that at least 4 of them are blue? Round your answer to the nearest whole percent.',
#  "A six-sided die is rolled 5 times. What is the probability of getting exactly three 6's? Give your answer as a simplified fraction.",
#  'In a survey of 200 people, 120 prefer coffee and 100 prefer tea. If a person is selected at random from this group, what is the probability that they like both coffee and tea, given that they like at least one of the two beverages?',
#  'A factory produces light bulbs with a 5% defect rate. If you randomly select 10 bulbs, what is the expected number of defective bulbs?',
#  'Here are 5 new math problems on Probability and Statistics:\n\nA continuous random variable Z follows the Cauchy distribution with probability density function f(z) = 1 / (π(1 + z^2)). Determine the probability density function of W = e^Z.',
#  'In a psychology experiment, reaction times are normally distributed with a mean of 250 ms and a standard deviation of 40 ms. What is the probability that a randomly selected participant has a reaction time between 200 ms and 300 ms? Give your answer as a percentage rounded to two decimal places.',
#  'A data scientist is analyzing the number of daily active users for a mobile app. The number of users follows a Poisson distribution with a mean of 5000. What is the probability of observing exactly 5200 active users on a given day? Express your answer in scientific notation.',
#  'Let X be a random variable with cumulative distribution function F(x) = 1 - e^(-x) for x ≥ 0 and 0 for x < 0. Find the probability density function of Y = X^2.',
#  'A biased coin has a 60% chance of landing heads. The coin is flipped repeatedly until the first tail appears. What is the expected number of flips needed to see the first tail?',
#  'Here are 5 new math problems on Probability and Statistics based on your instructions:\n\nA standard deck of 52 playing cards is shuffled. Cards are drawn one at a time without replacement until the first ace appears. What is the probability that exactly 10 cards are drawn?',
#  "In a game show, contestants must guess a 4-digit code. Each digit is randomly chosen from 0 to 9 with replacement. If a contestant's guess matches the actual code in at least two positions, they win a prize. Calculate the probability of winning, expressed as a percentage.",
#  'A biologist is studying a rare species of butterfly. In a given habitat, the probability of spotting this butterfly on any given day is 0.15. What is the expected number of days until the biologist spots the butterfly for the third time?',
#  'Six fair dice are rolled simultaneously. Determine the probability that the sum of the numbers shown is a prime number. Give your answer as a simplified fraction.',
#  'A quality control inspector examines electronic components. The probability of a component being defective is 0.03. If the inspector randomly selects 50 components, what is the probability that at least one is defective? Round your answer to four decimal places.',
#  'Here are 5 new math problems in Probability and Statistics based on your requirements:\n\nA deck of 52 cards contains 13 cards of each suit (hearts, diamonds, clubs, spades). Cards are drawn one at a time without replacement. If a pair of cards with the same rank (e.g., two kings) is drawn, both cards are discarded. The game ends when either 4 cards of different ranks are held or the deck is depleted. What is the probability that all cards will be drawn before the game ends?',
#  'In a laboratory, 8 distinct chemical compounds are stored in identical vials. A scientist randomly selects vials one at a time for testing. If two vials containing the same compound are selected consecutively, they are immediately used in an experiment and removed. The process continues until either 3 different compounds are held simultaneously or all vials have been tested. Calculate the expected number of vials tested before the process terminates.',
#  'A mobile app developer is beta testing a new game. The game has 10 unique levels, presented in random order. Players test levels sequentially, but if they encounter two consecutive levels with the same difficulty rating, those levels are marked as "balanced" and removed from the test pool. Testing stops if a player has 3 unbalanced levels in their queue or all levels have been tested. What\'s the probability, expressed as a percentage, that all levels will be tested?',
#  'At a carnival, there are 7 different types of prizes hidden in opaque boxes. A player selects boxes randomly, one at a time. If they find matching prizes in consecutive selections, those prizes are awarded and removed. The game concludes when the player accumulates 3 distinct, unmatched prizes or all boxes have been opened. Given that there are exactly two boxes for each prize type, what is the probability that the player will open all boxes before the game ends?',
#  "In a genetic study, researchers are analyzing 9 pairs of alleles. They randomly select alleles for sequencing, one at a time. When a matching pair is found, it's immediately set aside for further study. The analysis concludes if researchers have 3 unmatched alleles in their current set or if all alleles have been sequenced. What is the conditional probability that all alleles will be sequenced, given that at least 10 alleles have already been selected? Express your answer as a decimal rounded to four places.",
#  'Here are 5 new math problems on Probability and Statistics matching your criteria:\n\nA factory produces microchips, and their quality is rated on a scale from 0 to 10. Let [x] denote the greatest integer not exceeding x. A microchip is considered premium if [log₃(x+1)] is odd, where x is its quality rating. What is the probability that a randomly selected microchip from this factory is premium?',
#  'In a cryptography system, a key is generated as follows: A random real number between 0 and 100 is chosen, then rounded down to the nearest integer. The key is valid if this integer, when expressed in binary, has an odd number of digits. What is the percentage chance that a generated key is valid?',
#  "A data scientist is analyzing website traffic. Let f(x) = [e^x], where [y] represents the floor function (greatest integer not exceeding y). If x is the number of visitors per minute, the website is flagged for potential bot activity when f(ln(x)) is a multiple of 3. What's the probability that the website will be flagged if the number of visitors per minute is uniformly distributed between 0 and 100?",
#  'In a game show, contestants spin a wheel marked with real numbers from 0 to 2π. Let [x] denote the floor function. A contestant wins if [sin(x)] + [cos(x)] = 0, where x is the number on which the wheel stops. What is the expected number of spins before a contestant wins, assuming the wheel is fair?',
#  "A climate model predicts daily temperatures as real numbers. Let T be tomorrow's predicted temperature in Celsius, and define g(T) = [log₅(|T|+1)], where [x] is the floor function. If g(T) is prime, an extreme weather alert is issued. Assuming the model's predictions follow a normal distribution with mean 15°C and standard deviation 5°C, what is the probability of an extreme weather alert being issued?",
#  'Here are 5 new math problems on Probability and Statistics based on your requirements:\n\nA standard deck of 52 cards contains 13 hearts. If you draw 3 cards without replacement, what is the probability that all three cards are hearts? Express your answer as a decimal rounded to four decimal places.',
#  'In a bowl of 30 candies, there are 12 chocolate, 10 strawberry, and 8 lemon flavored pieces. If you select 2 candies at random, what is the percentage chance that both are the same flavor?',
#  "A six-sided die is rolled 5 times. What's the probability of getting exactly three 4s? Give your answer as a simplified fraction.",
#  'In a survey of 200 people, 80 prefer coffee, 70 prefer tea, and 30 like both. If a person is randomly selected from this group, what is the probability that they either like coffee or tea, but not both?',
#  'A bag contains 5 red marbles, 3 blue marbles, and 2 green marbles. Two marbles are drawn without replacement. Given that the first marble drawn is red, what is the probability that the second marble is also red?',
#  'Here are 5 new math problems on Probability and Statistics:\n\nA continuous random variable Z follows the Cauchy distribution with probability density function f(z) = 1 / (π * (1 + z^2)). Determine the probability density function of W = e^Z.',
#  'In a large population, height follows a normal distribution with mean μ and standard deviation σ. If a person is randomly selected and their height is cubed, what is the resulting distribution of this transformed variable?',
#  'The waiting time (in minutes) between customer arrivals at a coffee shop follows an exponential distribution with rate parameter λ = 0.1. What is the probability that the time until the next customer arrives is between 5 and 10 minutes?',
#  'A data scientist models the daily returns of a stock as a random variable Y with the Laplace distribution, having probability density function f(y) = (1 / (2b)) * exp(-|y - μ| / b), where μ is the location parameter and b is the scale parameter. Find the cumulative distribution function of Y.',
#  'The lifetime of a certain electronic component is modeled by a Weibull distribution with probability density function f(t) = (k/λ) * (t/λ)^(k-1) * exp(-(t/λ)^k), where k > 0 is the shape parameter and λ > 0 is the scale parameter. If a new variable S is defined as S = T^(1/k), what is the distribution of S?',
#  'Here are 5 new math problems on Probability and Statistics based on your requirements:\n\nA standard deck of 52 playing cards is shuffled. Cards are drawn one at a time without replacement until the first Ace appears. What is the probability that exactly 7 cards are drawn?',
#  'In a game show, contestants must open 3 out of 10 identical boxes. Eight boxes contain consolation prizes, while two contain cash prizes. If a contestant wins by finding at least one cash prize, what percentage of contestants are expected to win?',
#  'A six-sided die is rolled repeatedly until a 6 appears. Calculate the probability that the number of rolls needed is a multiple of 3.',
#  "An online poll asks voters to rank five candidates in order of preference. If 1000 people respond and each ranking is equally likely, what's the expected number of voters who will rank a specific candidate first?",
#  "A factory produces light bulbs with a 2% defect rate. Bulbs are packaged in boxes of 50. What's the probability that a randomly selected box contains no more than one defective bulb? Give your answer as a decimal rounded to four places."]

# %% [markdown]
# # Run Full Generation

# %%
# Full augmentation function
def augment_data(df, target_samples=3000, batch_size=5, max_workers=8):
    label_counts = df['label'].value_counts()
    augmented_data = []
    total_start_time = time.time()
    
    for label, count in label_counts.items():
        print(f"Processing label {label} ({TOPICS[label]}): {count} samples in data.")
        if count < target_samples:
            topic = TOPICS[label]
            samples_needed = target_samples - count
            original_questions = df[df['label'] == label]['Question'].tolist()
            if not original_questions:
                print(f"Error: No questions found for {topic}. Skipping...")
                continue
            new_questions = generate_questions_parallel(original_questions, topic, samples_needed, batch_size, max_workers)
            for q in new_questions:
                augmented_data.append({'Question': q, 'label': label})
    
    augmented_df = pd.DataFrame(augmented_data)
    total_elapsed = time.time() - total_start_time
    print(f"Total augmentation completed in {total_elapsed:.2f} seconds. Generated {len(augmented_df)} new questions.")
    return augmented_df

# Run full augmentation
if __name__ == "__main__":
    try:
        train_df = pd.read_csv(train_data_path)
        print("Loaded train.csv. Starting augmentation...")
        augmented_df = augment_data(train_df)
        output_file = 'augmented_train_second_attempt.csv'
        augmented_df.to_csv(output_file, index=False)
        print(f"Saved augmented data to {output_file}.")
    except FileNotFoundError:
        print("Error: train.csv not found.")
    except KeyError:
        print("Error: Required columns ('Question', 'label') not found. Available columns:", train_df.columns.tolist())
# Out:
# Loaded train.csv. Starting augmentation...
# Processing label 0 (Algebra): 2618 samples in data.
# Generating 382 questions in 77 batches...
# Generated 385 questions in 97.54 seconds.
# Processing label 1 (Geometry and Trigonometry): 2439 samples in data.
# Generating 561 questions in 113 batches...
# Generated 565 questions in 123.05 seconds.
# Processing label 5 (Combinatorics and Discrete Math): 1827 samples in data.
# Generating 1173 questions in 235 batches...
# Generated 1175 questions in 250.67 seconds.
# Processing label 4 (Number Theory): 1712 samples in data.
# Generating 1288 questions in 258 batches...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Generated 1285 questions in 300.46 seconds.
# Processing label 2 (Calculus and Analysis): 1039 samples in data.
# Generating 1961 questions in 393 batches...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Generated 1960 questions in 470.92 seconds.
# Processing label 3 (Probability and Statistics): 368 samples in data.
# Generating 2632 questions in 527 batches...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Generated 2635 questions in 661.91 seconds.
# Processing label 6 (Linear Algebra): 100 samples in data.
# Generating 2900 questions in 580 batches...
# Generated 2900 questions in 675.68 seconds.
# Processing label 7 (Abstract Algebra and Topology): 86 samples in data.
# Generating 2914 questions in 583 batches...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 3/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 3/3 after delay...
# Failed to generate questions after 3 attempts.
# Throttling detected. Retrying 2/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Throttling detected. Retrying 1/3 after delay...
# Generated 2865 questions in 677.45 seconds.
# Total augmentation completed in 3257.76 seconds. Generated 13758 new questions.
# Saved augmented data to augmented_train.csv.
